# %%
### Operadores aritmeticos ###



# Operaciones con enteros
#print(3 + 4)
#print(3 - 4)
#print(3 * 4)
#print(3 / 4)
#print(10 % 3)
#print(10 // 3)
#print(2 ** 3)
#print(2 ** 3 + 3 - 7 / 1 // 4)

# Operaciones  con cadena
#print("Hola " + "Python " + "¿Que Tal?")
#print("Hola" + str(5))


# Operaciones mixtas
#print("Hola " * 5)
#print("Hola " * (2 ** 3))

#my_float = 2.5 * 2
#print("Hola " * int(my_float))

# Opraciones con enteros
#print(3 > 4)
#print(3 < 4)
#print(3 >= 4)
#print(4 <= 4)
#print(3 == 4)
#print(3 != 4)

# Operaciones con cadena de texto
#print("Hola" > "Python")
#print("Hola" < "Python")
#print("aaaa" >= "abaa")  # Ordenacion alfabetica por ASCII
#print(len("aaaa") >= len("aaaa"))  #Cuenta caracteres
#print("Hola" <= "Python")
#print("Hola" == "Python")
#print("Hola" != "Python")

### Operaciones Logicos ###

# Basada en ALgedra de Boole
#print(3 < 4 and "Hala" > "Python")
#print(3 > 4 or "Hala" > "Python")
#print(3 < 4 and "Hala" < "Python")
#print(3 < 4 or "Hala" > "Python")
#print(3 < 4 or ("Hala" > "Python" and 4 == 4))
#print(not (3 > 4))
