# %%
### String ###

#my_string = "Mi String"
#my_other_string = 'Mi otro String'

#print(len(my_string))
#print(len(my_other_string))
#print(my_string + " " + my_other_string)

# Un separodor para ubicarme

#my_ne_line_string = "Este es un String\ncom salto de linea"
#print(my_ne_line_string)

#my_tap_string = "\tEste es un string con tabulacion"
#print(my_tap_string)

#my_scape_string = "\\tEste es un String \\n escapado"
#print(my_scape_string)

# Un separador para ubicarme


# Formateo
#name, surname, age ="Gabriel", "Garcia", 16
#print("Mi nombre es {} {} y mi edad es {}" .format( name, surname, age))
#print("Mi nombre es %s %s y mi edad es %d" % ( name, surname, age))
#print("Mi nombre es " + name + " " + surname + " y mi edad es " + str(age))
#print(f"Mi nombre es {name} {surname} y mi edad es {age}")

# Un separador para poder ubicarme

# Desempaqueado de caracteres

language = "python"
#a, b, c, d, e, f = language
#print(a)
#print(e)

# División

#language_slice = language[1:3]
#print(language_slice)

#language_slice = language[1:]
#print(language_slice)

#language_slice = language[-2]
#print(language_slice)

#language_slice = language[0:6:2]
#print(language_slice)

# Reverse

reversed_language = language[::-1]
print(reversed_language)

 # Funcion de lemguaje

#print(language.capitalize())
#print(language.upper())
#print(language.count("t"))
#print(language.isnumeric())
#print("1".isnumeric())
#print(language.lower())
#print(language.lower().isupper())
#print(language.startswith("Py"))
#print("Py" == "py")  # No es lo mismo
# Out:
# nohtyp
