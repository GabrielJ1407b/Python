# %%
### Conditionls ###
# if

my_condition = False

if my_condition: # Eslo mismo que el if my_condition == True:
    print("Se ejecuta la condision del if")

my_condition = 5 * 5

if my_condition == 10:
  print("Se ejecuta la condision del if")

  # if, elif, else

if my_condition > 10 and my_condition < 20:
    print("Es mayor que 10 y menor que 20")
elif my_condition == 25:
    print("Es igual que 25")
else:
  print("Es menor o igual que 10 o mayor o igual que 20 o distinto que 15")

print("la ejecucion continua")

# Condicional con ispeccion de valor

my_string = ""

if not my_string:
  print("Mi cadena de texto esta vacio")

if my_string == "Mi cadena de textooooooo":
   print("Esta cadena de texto coinciden")
# Out:
# Es igual que 25
# la ejecucion continua
# Esta cadena de texto coinciden
